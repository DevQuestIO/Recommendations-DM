# %%
# !pip install pandas numpy scikit-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("preprocessed_data.csv")
df.head()
# Out:
#    id  page_number  is_premium  \
# 0   1            1       False
# 1   2            1       False
# 2   3            1       False
# 3   4            1       False
# 4   5            1       False
#
#                                                title  \
# 0                                         1. Two Sum
# 1                                 2. Add Two Numbers
# 2  3. Longest Substring Without Repeating Characters
# 3                     4. Median of Two Sorted Arrays
# 4                   5. Longest Palindromic Substring
#
#                                  problem_description  \
# 0  Given an array of integers nums and an integer...
# 1  You are given two non-empty linked lists repre...
# 2  Given a string s, find the length of the longe...
# 3  Given two sorted arrays nums1 and nums2 of siz...
# 4  Given a string s, return the longest palindrom...
#
#                                        topic_tags difficulty  \
# 0                           'Array', 'Hash Table'       Easy
# 1              'Linked List', 'Math', 'Recursion'     Medium
# 2        'Hash Table', 'String', 'Sliding Window'     Medium
# 3  'Array', 'Binary Search', 'Divide and Conquer'       Hard
# 4                 'String', 'Dynamic Programming'     Medium
#
#                                    similar_questions  no_similar_questions  \
# 0  ["'3Sum'", "'4Sum'", "'Two Sum II - Input Arra...                  21.0
# 1  ["'Multiply Strings'", "'Add Binary'", "'Sum o...                   8.0
# 2  ["'Longest Substring with At Most Two Distinct...                   9.0
# 3           ["'Median of a Row Wise Sorted Matrix'"]                   1.0
# 4  ["'Shortest Palindrome'", "'Palindrome Permuta...                   6.0
#
#    acceptance    accepted  submission  solution  discussion_count    likes  \
# 0        51.0  11300000.0  22100000.0   26800.0             638.0  52700.0
# 1        41.5   4000000.0   9700000.0   15700.0             428.0  28900.0
# 2        34.1   5100000.0  14900000.0   18100.0             237.0  37700.0
# 3        38.3   2200000.0   5800000.0   14100.0             304.0  26600.0
# 4        33.2   2700000.0   8200000.0    9600.0             225.0  27900.0
#
#    dislikes                                        problem_URL  \
# 0    1700.0              https://leetcode.com/problems/two-sum
# 1    5600.0      https://leetcode.com/problems/add-two-numbers
# 2    1700.0  https://leetcode.com/problems/longest-substrin...
# 3    2900.0  https://leetcode.com/problems/median-of-two-so...
# 4    1600.0  https://leetcode.com/problems/longest-palindro...
#
#                                         solution_URL
# 0     https://leetcode.com/problems/two-sum/solution
# 1  https://leetcode.com/problems/add-two-numbers/...
# 2  https://leetcode.com/problems/longest-substrin...
# 3  https://leetcode.com/problems/median-of-two-so...
# 4  https://leetcode.com/problems/longest-palindro...

# %%
from sentence_transformers import SentenceTransformer

# Load pre-trained Sentence-BERT model
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Define weights for title, topic tags, and description embeddings
TITLE_WEIGHT = 0.35
TAGS_WEIGHT = 0.35
DESCRIPTION_WEIGHT = 0.3

# Generate Sentence-BERT embeddings
print("Generating Sentence-BERT embeddings for components...")

# Title embeddings
title_embeddings = sbert_model.encode(df["title"].fillna(''), show_progress_bar=True)
title_embeddings_weighted = np.array(title_embeddings) * TITLE_WEIGHT

# Topic tags embeddings
tags_embeddings = sbert_model.encode(df["topic_tags"].fillna(''), show_progress_bar=True)
tags_embeddings_weighted = np.array(tags_embeddings) * TAGS_WEIGHT

# Problem description embeddings
description_embeddings = sbert_model.encode(df["problem_description"].fillna(''), show_progress_bar=True)
description_embeddings_weighted = np.array(description_embeddings) * DESCRIPTION_WEIGHT

print("Embeddings for title, tags, and descriptions generated and weighted.")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Generating Sentence-BERT embeddings for components...
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Embeddings for title, tags, and descriptions generated and weighted.

# %%
X_combined = np.hstack([
    title_embeddings_weighted,
    tags_embeddings_weighted,
    description_embeddings_weighted
])

print("Shape of Final Combined Sentence-BERT Embedding Matrix:", X_combined.shape)
# Out:
# Shape of Final Combined Sentence-BERT Embedding Matrix: (3000, 1152)

# %%
def parse_similar_problems(similar_problems_str):
    if pd.isna(similar_problems_str):
        return []
    # Strip brackets and split by comma, then clean each string
    similar_problems_str = similar_problems_str.strip("[]")
    return [problem.strip().strip("'\"") for problem in similar_problems_str.split(",")]

# Add a column with parsed similar problems as lists
df["similar_problems_list"] = df["similar_questions"].apply(parse_similar_problems)
df.head()
# Out:
#    id  page_number  is_premium  \
# 0   1            1       False
# 1   2            1       False
# 2   3            1       False
# 3   4            1       False
# 4   5            1       False
#
#                                                title  \
# 0                                         1. Two Sum
# 1                                 2. Add Two Numbers
# 2  3. Longest Substring Without Repeating Characters
# 3                     4. Median of Two Sorted Arrays
# 4                   5. Longest Palindromic Substring
#
#                                  problem_description  \
# 0  Given an array of integers nums and an integer...
# 1  You are given two non-empty linked lists repre...
# 2  Given a string s, find the length of the longe...
# 3  Given two sorted arrays nums1 and nums2 of siz...
# 4  Given a string s, return the longest palindrom...
#
#                                        topic_tags difficulty  \
# 0                           'Array', 'Hash Table'       Easy
# 1              'Linked List', 'Math', 'Recursion'     Medium
# 2        'Hash Table', 'String', 'Sliding Window'     Medium
# 3  'Array', 'Binary Search', 'Divide and Conquer'       Hard
# 4                 'String', 'Dynamic Programming'     Medium
#
#                                    similar_questions  no_similar_questions  \
# 0  ["'3Sum'", "'4Sum'", "'Two Sum II - Input Arra...                  21.0
# 1  ["'Multiply Strings'", "'Add Binary'", "'Sum o...                   8.0
# 2  ["'Longest Substring with At Most Two Distinct...                   9.0
# 3           ["'Median of a Row Wise Sorted Matrix'"]                   1.0
# 4  ["'Shortest Palindrome'", "'Palindrome Permuta...                   6.0
#
#    acceptance    accepted  submission  solution  discussion_count    likes  \
# 0        51.0  11300000.0  22100000.0   26800.0             638.0  52700.0
# 1        41.5   4000000.0   9700000.0   15700.0             428.0  28900.0
# 2        34.1   5100000.0  14900000.0   18100.0             237.0  37700.0
# 3        38.3   2200000.0   5800000.0   14100.0             304.0  26600.0
# 4        33.2   2700000.0   8200000.0    9600.0             225.0  27900.0
#
#    dislikes                                        problem_URL  \
# 0    1700.0              https://leetcode.com/problems/two-sum
# 1    5600.0      https://leetcode.com/problems/add-two-numbers
# 2    1700.0  https://leetcode.com/problems/longest-substrin...
# 3    2900.0  https://leetcode.com/problems/median-of-two-so...
# 4    1600.0  https://leetcode.com/problems/longest-palindro...
#
#                                         solution_URL  \
# 0     https://leetcode.com/problems/two-sum/solution
# 1  https://leetcode.com/problems/add-two-numbers/...
# 2  https://leetcode.com/problems/longest-substrin...
# 3  https://leetcode.com/problems/median-of-two-so...
# 4  https://leetcode.com/problems/longest-palindro...
#
#                                similar_problems_list
# 0  [3Sum, 4Sum, Two Sum II - Input Array Is Sorte...
# 1  [Multiply Strings, Add Binary, Sum of Two Inte...
# 2  [Longest Substring with At Most Two Distinct C...
# 3               [Median of a Row Wise Sorted Matrix]
# 4  [Shortest Palindrome, Palindrome Permutation, ...

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split


mlb = MultiLabelBinarizer()
y = mlb.fit_transform(df["similar_problems_list"])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, random_state=42)

print("Data split into training and testing sets.")
# Out:
# Data split into training and testing sets.

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

logreg_model = OneVsRestClassifier(LogisticRegression(solver='liblinear'))
logreg_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 3 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 6 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 17 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 63 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 74 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 75 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 78 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 92 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 94 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 105 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 109 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 126 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 134 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 135 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 138 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 158 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 163 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 176 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 178 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 179 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 181 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 184 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 192 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 193 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 195 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 206 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 221 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 224 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 249 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 256 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 258 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 262 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 277 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 282 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 285 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 298 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 304 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 315 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 342 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 363 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 384 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 412 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 416 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 422 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 425 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 440 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 444 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 451 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 466 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 470 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 480 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 483 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 486 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 489 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 496 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 499 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 526 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 546 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 547 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 555 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 560 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 579 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 584 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 597 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 599 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 602 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 611 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 623 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 625 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 626 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 629 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 634 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 644 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 658 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 677 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 685 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 701 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 704 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 708 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 709 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 710 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 713 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 720 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 737 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 739 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 741 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 762 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 769 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 775 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 794 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 800 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 807 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 811 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 816 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 818 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 830 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 836 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 842 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 848 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 860 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 861 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 865 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 878 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 887 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 896 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 909 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 914 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 919 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 920 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 922 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 938 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 941 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 944 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 955 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 980 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 983 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 986 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 995 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 998 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1007 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1009 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1019 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1020 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1035 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1038 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1054 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1061 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1065 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1079 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1091 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1094 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1102 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1105 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1146 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1152 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1159 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1169 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1170 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1171 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1173 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1191 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1192 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1195 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1233 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1242 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1250 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1274 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1301 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1308 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1309 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1310 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1311 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1326 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1336 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1350 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1365 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1369 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1378 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1383 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1399 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1406 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1442 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1443 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1446 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1453 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1459 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1469 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1473 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1499 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1509 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1510 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1536 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1538 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1539 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1540 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1547 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1565 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1571 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/multiclass.py:87: UserWarning: Label not 1572 is present in all training examples.
#   warnings.warn(
# OneVsRestClassifier(estimator=LogisticRegression(solver='liblinear'))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, hamming_loss
from sklearn.preprocessing import MultiLabelBinarizer

print("Generating Sentence-BERT embeddings for title, tags, and descriptions...")

title_embeddings = sbert_model.encode(df["title"].fillna(''), show_progress_bar=True)
tags_embeddings = sbert_model.encode(df["topic_tags"].fillna(''), show_progress_bar=True)
description_embeddings = sbert_model.encode(df["problem_description"].fillna(''), show_progress_bar=True)

print("Embeddings generated for all components.")
# Out:
# Generating Sentence-BERT embeddings for title, tags, and descriptions...
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Embeddings generated for all components.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def clean_recommendation_title(title):
    # Remove leading numbers and periods (e.g., "1. Two Sum" -> "Two Sum")
    return title.split('. ', 1)[-1].strip()

def hybrid_predict_sbert_weighted(title, topic_tags, description, model, mlb, title_embeddings, tags_embeddings, description_embeddings, df, top_k=5):
    """
    Predict similar questions using weighted Sentence-BERT embeddings and title-based similarity.
    """
    # Step 1: Compute Sentence-BERT embeddings for the input
    title_embedding = sbert_model.encode([title]) * TITLE_WEIGHT
    tags_embedding = sbert_model.encode([topic_tags]) * TAGS_WEIGHT
    description_embedding = sbert_model.encode([description]) * DESCRIPTION_WEIGHT

    # Combine weighted embeddings
    combined_embedding = np.hstack([title_embedding, tags_embedding, description_embedding])

    # Step 2: Model predictions
    model_pred = model.predict(combined_embedding)
    model_predicted_labels = mlb.inverse_transform(model_pred)

    # Step 3: Title-based similarity
    title_similarity_scores = cosine_similarity(title_embedding, title_embeddings).flatten()
    top_indices = title_similarity_scores.argsort()[-top_k:][::-1]
    title_similar_questions = [df.iloc[idx]["title"] for idx in top_indices]

    # Step 4: Combine predictions
    combined_predictions = list(set(title_similar_questions) | set(model_predicted_labels[0]))

    # Step 5: Cleanup predictions
    predicted_labels = pd.Series(combined_predictions)
    predicted_labels = predicted_labels.map(clean_recommendation_title)
    return predicted_labels.tolist()

# %%
def evaluate_hybrid_model_weighted(df, model, mlb, title_embeddings, tags_embeddings, description_embeddings, top_k=5):
    """
    Evaluate the hybrid model using Sentence-BERT embeddings for title, tags, and descriptions.
    """
    y_true = []
    y_pred = []

    for idx, row in df.iterrows():
        title = row["title"]
        topic_tags = row["topic_tags"]
        description = row["problem_description"]
        ground_truth = row["similar_problems_list"]

        if not ground_truth:
            continue

        # Hybrid predictions
        predicted_labels = hybrid_predict_sbert_weighted(
            title, topic_tags, description, model, mlb,
            title_embeddings, tags_embeddings, description_embeddings,
            df, top_k=top_k
        )
        # predicted_labels = pd.Series(predicted_labels)
        # predicted_labels = predicted_labels.map(clean_recommendation_title)
        # predicted_labels = predicted_labels.tolist()

        # Convert to binary format
        y_true.append([1 if label in ground_truth else 0 for label in mlb.classes_])
        y_pred.append([1 if label in predicted_labels else 0 for label in mlb.classes_])

    # Convert to numpy arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # Compute metrics
    hamming = hamming_loss(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average="micro")
    recall = recall_score(y_true, y_pred, average="micro")
    f1 = f1_score(y_true, y_pred, average="micro")

    print("\nUpdated Hybrid Model Evaluation Results:")
    print(f"Hamming Loss: {hamming:.4f}")
    print(f"Precision@k: {precision:.4f}")
    print(f"Recall@k: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

# %%
TITLE_WEIGHT = 0.35
TAGS_WEIGHT = 0.35
DESCRIPTION_WEIGHT = 0.3

# Evaluate the updated hybrid model
evaluate_hybrid_model_weighted(
    df, logreg_model, mlb, title_embeddings, tags_embeddings, description_embeddings, top_k=5
)
# Out:
# Updated Hybrid Model Evaluation Results:
# Hamming Loss: 0.0025
# Precision@k: 0.7500
# Recall@k: 0.6200
# F1-Score: 0.6788
