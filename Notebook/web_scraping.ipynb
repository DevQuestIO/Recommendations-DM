# %% [markdown]
# <center><h1>Scraping LeetCode Problem Details Using Python, Selenium & BeautifulSoup</h1></center>

# %% [markdown]
# <center>
#     <a href="https://leetcode.com/">
#          <img src="https://i.imgur.com/9aLyuqU.png" width=100px style="box-shadow:rgba(52, 64, 77, 0.2) 0px 1px 5px 0px;border-radius:4px;">
#     </a>
# </center>

# %% [markdown]
# <h2> Web Scraping </h2>

# %% [markdown]
# - Web Scraping is the process of deriving data from a website using a computer program. The program scrapes for HTML code, which is the standard markup that websites display content.

# %% [markdown]
# <h2> List of the tools used in this Notebook </h2>

# %% [markdown]
# - **Python**
# - **Selenium**
# - **Beautiful Soup**

# %% [markdown]
# <h2> About LeetCode </h2>

# %% [markdown]
# - LeetCode is your ultimate platform for skill enhancement, knowledge expansion, and effective technical interview preparation, offering a vast library of 3000+ coding problems.

# %% [markdown]
#  <center><a href="https://leetcode.com/problemset/all/"><img src="https://i.imgur.com/lyJxDDz.png" style="box-shadow:rgba(52, 64, 77, 0.2) 0px 1px 5px 0px;border-radius:10px;" width=800px></a></center>

# %% [markdown]
# <center><h3> First Part </h3></center>

# %% [markdown]
# - First we will be scraping all problems list.
# - The first section of the website is the problem set table that contains all the problems.
# - There are over 3000+ problems, distributed over 60 pages.The first section of the website is the problem set table that contains all the problems.
#
# <center><a href="https://leetcode.com/problemset/all/"><img src="https://i.imgur.com/giQr7yk.png" style="box-shadow:rgba(52, 64, 77, 0.2) 0px 1px 5px 0px;border-radius:10px;" width=75%></a></center>
#
# **The details we are scraping from the first section are:**
#
# 1. Title
# 2. Problem_URL
# 3. Solution_URL
# 4. Acceptance
# 5. Difficulty

# %% [markdown]
# <center><h3> Second Part </h3></center>

# %% [markdown]
# - Second we will scrape the problem information from every problem page.
# - we need to scrape 3000 problem pages because we have 3000 problems.
#
# <div style="display: flex;">
#   <div style="flex: 1; margin-right: 10px;">
#     <a href="https://leetcode.com/problems/4sum/">
#       <img src="https://i.imgur.com/5BwD2nb.png" style="box-shadow:rgba(52, 64, 77, 0.2) 0px 1px 5px 0px;border-radius:10px;width: 100%;">
#     </a>
#   </div>
#   <div style="flex: 1; margin-right: 10px;">
#     <a href="https://leetcode.com/problems/4sum/">
#       <img src="https://i.imgur.com/ozWPDVj.png" style="box-shadow:rgba(52, 64, 77, 0.2) 0px 1px 5px 0px;border-radius:10px;width: 100%;">
#     </a>
#   </div>
#   <div style="flex: 1;">
#     <a href="https://leetcode.com/problems/4sum/">
#       <img src="https://i.imgur.com/QETFefW.png" style="box-shadow:rgba(52, 64, 77, 0.2) 0px 1px 5px 0px;border-radius:10px;width: 100%;">
#     </a>
#   </div>
# </div>
#
# **The details we are scraping from the second section are:**
#
# 1. Premium Status
# 2. Title
# 3. Problem Description
# 4. Topic Tags
# 5. Accepted
# 6. Submission
# 7. Solution
# 8. Discussion Count
# 9. Likes
# 10. Dislikes
# 11. Similar Questions

# %% [markdown]
# <center><h3> Third Part </h3></center>

# %% [markdown]
# - This is the last part.
# - Combine both part of The DataFrame.
# - Analyzing Data Availability

# %% [markdown]
# <h2> Scraping First Section: </h2>

# %% [markdown]
# `Importing And Installing Relevant Libraries`:

# %%
# !pip3 install pandas bs4 selenium
# Out:
# Requirement already satisfied: pandas in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: bs4 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: selenium in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (4.27.1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: tzdata>=2022.7 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: beautifulsoup4 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: trio~=0.17 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from selenium) (0.27.0)
# Requirement already satisfied: websocket-client~=1.8 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from selenium) (2.2.3)
# Requirement already satisfied: six>=1.5 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: exceptiongroup in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: idna in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: wsproto>=0.14 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/puneetbajaj/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import time  # For handling time-related functions
import re  # For regular expressions
import numpy as np  # For numerical operations
import pandas as pd  # For data manipulation and analysis
from bs4 import BeautifulSoup  # For web scraping
from selenium import webdriver  # For browser automation
from selenium.webdriver.chrome.service import Service  # For configuring the ChromeDriver service

# %% [markdown]
# `Functions that help scraping first section`:
#
# 1. `get_driver`:
#    - Returns a configured instance of the Chrome WebDriver for web scraping.
# ---
# 2. `get_page_source(url, delay=10)`:
#    - Gets the page source of a specified URL using Selenium and BeautifulSoup.
#    - Optional delay parameter to wait for the page to load.
# ---
# 3. `get_titles(page_source, first_page=False)`:
#    - Extracts titles of problems from the page source.
#    - Optional parameter `first_page` to handle starting index.
# ---
# 4. `get_problems_URL(page_source, first_page=False)`:
#    - Extracts URLs of problems from the page source.
#    - Optional parameter `first_page` to handle starting index.
# ---
# 5. `get_acceptances_difficulties(page_source, first_page=False)`:
#    - Extracts acceptance rates and difficulties of problems from the page source.
#    - Optional parameter `first_page` to handle starting index.
# ---
# 6. `get_single_page_df(url, first_page=False)`:
#    - Combines the above functions to create a Pandas DataFrame for a single page of problems.
# ---
# 7. `get_multiple_page_df(start=1, end=60)`:
#    - Calls `get_single_page_df` for a range of pages and concatenates the results into a single DataFrame.
# ---
# 8. `scrape(start=1, end=60, file_name='part1.csv')`:
#    - Initiates the scraping process, saving the resulting DataFrame to a CSV file.

# %% [markdown]
# 1. `get_driver`:
#    - Returns a configured instance of the Chrome WebDriver for web scraping.

# %%
def get_driver():
    """
    Creates and configures a Chrome WebDriver instance for web scraping.

    Returns:
        WebDriver: Configured instance of the Chrome WebDriver.
    """
    # Set the path to the ChromeDriver executable
    service = Service('/opt/homebrew/bin/chromedriver')

    # Configure Chrome options
    options = webdriver.ChromeOptions()
    
    # Ignore certificate errors
    options.add_argument('--ignore-certificate-errors')
    
    # Start the browser in maximized mode
    options.add_argument('--start-maximized')

    # Create a Chrome WebDriver instance with the specified service and options
    driver = webdriver.Chrome(service=service, options=options)

    # Return the WebDriver instance
    return driver

# %% [markdown]
# 2. `get_page_source(url, delay=10)`:
#    - Gets the page source of a specified URL using Selenium and BeautifulSoup.
#    - Optional delay parameter to wait for the page to load.

# %%
def get_page_source(url, delay=10):
    """
    Retrieves the page source of a specified URL using Selenium and BeautifulSoup.

    Args:
        url (str): The URL to scrape.
        delay (int, optional): Delay in seconds to wait for the page to load. Default is 10 seconds.

    Returns:
        BeautifulSoup: The BeautifulSoup object representing the page source.
    """
    # Get a Chrome WebDriver instance
    driver = get_driver()

    # Open the specified URL in the browser
    driver.get(url)

    # Allow time for the page to load (adjust delay as needed)
    time.sleep(delay)

    # Get the page source using BeautifulSoup for parsing
    page_source = BeautifulSoup(driver.page_source, 'html.parser')

    # Close the WebDriver to release resources
    driver.quit()

    # Return the parsed page source
    return page_source

# %% [markdown]
# 3. `get_titles(page_source, first_page=False)`:
#    - Extracts titles of problems from the page source.
#    - Optional parameter `first_page` to handle starting index.

# %%
def get_titles(page_source, first_page=False):
    """
    Extracts titles of problems from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.
        first_page (bool, optional): Flag indicating whether it's the first page. Default is False.

    Returns:
        list: List of extracted titles.
    """
    # Determine the starting index based on whether it's the first page or not
    start_index = 1 if first_page else 0

    # Find all title elements using BeautifulSoup
    title_elements = page_source.find_all(
        'a',
        class_=[
            'h-5 hover:text-blue-s dark:hover:text-dark-blue-s',
            'h-5 hover:text-blue-s dark:hover:text-dark-blue-s opacity-60'
        ]
    )[start_index:]

    # Extract text from title elements and store in a list
    titles = [title_element.text for title_element in title_elements]

    # Return the list of titles
    return titles

# %% [markdown]
# 4. `get_problems_URL(page_source, first_page=False)`:
#    - Extracts URLs of problems from the page source.
#    - Optional parameter `first_page` to handle starting index.

# %%
def get_problems_URL(page_source, first_page=False):
    """
    Extracts URLs of problems from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.
        first_page (bool, optional): Flag indicating whether it's the first page. Default is False.

    Returns:
        list: List of extracted problem URLs.
    """
    # Determine the starting index based on whether it's the first page or not
    start_index = 1 if first_page else 0

    # Find all problem elements with an 'a' tag and an 'href' attribute using BeautifulSoup
    problem_elements = page_source.find_all('a', href=True, class_=[
        'h-5 hover:text-blue-s dark:hover:text-dark-blue-s',
        'h-5 hover:text-blue-s dark:hover:text-dark-blue-s opacity-60'
    ])[start_index:]

    # Extract the 'href' attribute values from the problem elements and store in a list
    problems_url = [el['href'] for el in problem_elements]

    # Return the list of problem URLs
    return problems_url

# %% [markdown]
# 5. `get_acceptances_difficulties(page_source, first_page=False)`:
#    - Extracts acceptance rates and difficulties of problems from the page source.
#    - Optional parameter `first_page` to handle starting index.

# %%
def get_acceptances_difficulties(page_source, first_page=False):
    """
    Extracts acceptances and difficulties of problems from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.
        first_page (bool, optional): Flag indicating whether it's the first page. Default is False.

    Returns:
        tuple: Two lists - acceptances and difficulties.
    """
    # Find all div elements with the specified class using BeautifulSoup
    div_elements = page_source.find_all('div', class_='mx-2 flex items-center py-[11px]')

    # Determine the starting index based on whether it's the first page or not
    start_index = 1 if first_page else 0

    # Extract text from the span elements within the div elements and store in a list
    items = [
        span_element.text.strip()
        for div_element in div_elements
        for span_element in [div_element.find('span')]
        if span_element
    ]

    # Separate the items into acceptances and difficulties lists
    acceptances, difficulties = [], []
    for item in items:
        if item:
            (acceptances if item.endswith('%') else difficulties).append(item)

    # Adjust lists based on the starting index
    acceptances = acceptances[start_index:]
    difficulties = difficulties[start_index:]

    # Return the lists of acceptances and difficulties
    return acceptances, difficulties

# %% [markdown]
# 6. `get_single_page_df(url, first_page=False)`:
#    - Combines the above functions to create a Pandas DataFrame for a single page of problems.

# %%
def get_single_page_df(url, first_page=False):
    """
    Creates a Pandas DataFrame for a single page of problems.

    Args:
        url (str): The URL of the page to scrape.
        first_page (bool, optional): Flag indicating whether it's the first page. Default is False.

    Returns:
        DataFrame: Pandas DataFrame containing titles, problem URLs, acceptances, and difficulties.
    """
    # Get the page source for the specified URL
    page_source = get_page_source(url)

    # Extract titles, problem URLs, acceptances, and difficulties from the page source
    titles = get_titles(page_source, first_page)
    problems_url = get_problems_URL(page_source, first_page)
    acceptances, difficulties = get_acceptances_difficulties(page_source, first_page)

    # Create a dictionary with the extracted data
    data = {
        'title': titles,
        'problem_URL': problems_url,
        'acceptance': acceptances,
        'difficulty': difficulties
    }

    # Create a DataFrame using the dictionary
    df = pd.DataFrame(data)

    # Return the DataFrame
    return df

# %% [markdown]
# 7. `get_multiple_page_df(start=1, end=60)`:
#    - Calls `get_single_page_df` for a range of pages and concatenates the results into a single DataFrame.

# %%
def get_multiple_page_df(start=1, end=60):
    """
    Calls get_single_page_df for a range of pages and concatenates the results into a single DataFrame.

    Args:
        start (int, optional): The starting page. Default is 1.
        end (int, optional): The ending page. Default is 60.

    Returns:
        DataFrame: Pandas DataFrame containing titles, problem URLs, acceptances, and difficulties for multiple pages.
    """
    # Initialize an empty list to store DataFrames for each page
    list_of_dfs = []

    # Set the flag for the first page
    first_page = True if start == 1 else False

    # Iterate over the specified range of pages
    for i in range(start, end + 1):
        # Construct the URL for the current page
        url = 'https://leetcode.com/problemset/all/?page=' + str(i)

        # Get the DataFrame for the current page and append it to the list
        df = get_single_page_df(url, first_page)
        list_of_dfs.append(df)

        # Update the first_page flag for subsequent pages
        first_page = False

    # Concatenate the list of DataFrames into a single DataFrame
    df = pd.concat(list_of_dfs, ignore_index=True)

    # Return the final DataFrame
    return df

# %% [markdown]
# 8. `scrape(start=1, end=60, file_name='part1.csv')`:
#    - Initiates the scraping process, saving the resulting DataFrame to a CSV file.

# %%
def scrape(start=1, end=60, file_name='part1.csv'):
    """
    Initiates the scraping process, saving the resulting DataFrame to a CSV file.

    Args:
        start (int, optional): The starting page for scraping. Default is 1.
        end (int, optional): The ending page for scraping. Default is 60.
        file_name (str, optional): The name of the CSV file to save the scraped data. Default is 'part1.csv'.
    """
    # Get the DataFrame by scraping multiple pages
    df = get_multiple_page_df(start, end)

    # Save the DataFrame to a CSV file
    df.to_csv(path_or_buf=file_name, index=False)

# %% [markdown]
# `Running Web-Scraping Process`:

# %%
scrape(start=1, end=60, file_name='x1.csv')

# %% [markdown]
# <p>This is the sample Dataframe : </p>

# %% [markdown]
# <img src="https://i.imgur.com/bj5NPGA.png">

# %% [markdown]
# `Data preprocessing in first section`:

# %% [markdown]
# - We need to convert `problem_URL` to proper url format.
# - We need to add `solution_URL` column in this dataframe.

# %%
df1 = pd.read_csv('x1.csv')

# %%
df1['problem_URL'] = df1['problem_URL'].apply(lambda x: f'{"https://leetcode.com"}{x}')

# %%
df1['solution_URL'] = df1['problem_URL'].apply(lambda x: f'{x}{"/solution"}')

# %% [markdown]
# <p>Now we are done with preprocssing: </p>

# %% [markdown]
# <img src="https://i.imgur.com/7gUlYSg.png">

# %% [markdown]
# <center> <h2 style="color:blue"> Result of First Section: </h2> </center>

# %% [markdown]
# <p>This is the sample Dataframe : </p>

# %% [markdown]
# <img src="https://i.imgur.com/Z70wkgZ.png">

# %% [markdown]
# <h2> Scraping Second Section: </h2>

# %% [markdown]
# `Functions that help scraping second section`:
#
# 1. `get_title(page_source)`:
#    - Extracts the title from the given page source.
# ---
# 2. `get_problem_description(page_source)`:
#    - Extracts the problem description from the given page source.
# ---
# 3. `get_topic_tags(page_source)`:
#     - Extracts topic tags from the given page source.
# ---
# 4. `get_accepted(page_source)`:
#     - Extracts the number of accepted submissions from the given page source.
# ---
# 5. `get_submission(page_source)`:
#     - Extracts the number of total submissions from the given page source.
# ---
# 6. `get_solution(page_source)`:
#     - Extracts the solution count from the given page source.
# ---
# 7. `get_discussion_count(page_source)`:
#     - Extracts the count of discussions from the given page source.
# ---
# 8. `get_likes(page_source)`:
#     - Extracts the number of likes from the given page source.
# ---
# 9. `get_dislikes(page_source)`:
#     - Extracts the number of dislikes from the given page source.
# ---
# 10. `get_similar_questions(page_source)`:
#     - Extracts a list of similar questions from the given page source.
# ---
# 11. `get_page_source(url, delay=10)`:
#     - Retrieves the page source of a specified URL using Selenium and BeautifulSoup.
# ---
# 12. `get_ispremium(page_source)`:
#     - Checks if the page indicates a premium status.
# ---
# 13. `scrape(df1, start=1, end=3000, file_name='x2.csv')`:
#     - Scrapes data for a range of links from the provided DataFrame and saves it to a CSV file.

# %% [markdown]
# 1. `get_title(page_source)`:
#    - Extracts the title from the given page source.

# %%
def get_title(page_source):
    """
    Extracts the title from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: The extracted title text.
    """
    # Find the title element using BeautifulSoup
    title_element = page_source.find(
        'a',
        class_='no-underline hover:text-blue-s dark:hover:text-dark-blue-s truncate cursor-text whitespace-normal hover:!text-[inherit]'
    )

    # Extract the text content from the title element
    title = title_element.text

    # Return the title
    return title

# %% [markdown]
# 2. `get_problem_description(page_source)`:
#    - Extracts the problem description from the given page source.

# %%
def get_problem_description(page_source):
    """
    Extracts the problem description from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: The extracted problem description text.
    """
    # Find the div element containing the problem description using BeautifulSoup
    description_element = page_source.find(
        'div',
        class_='elfjS'
    )

    # Extract the text content from the description element
    description_text = description_element.text

    # Return the problem description
    return description_text

# %% [markdown]
# 3. `get_topic_tags(page_source)`:
#    - Extracts topic tags from the given page source.

# %%
def get_topic_tags(page_source):
    """
    Extracts the topic tags from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: Comma-separated string of extracted topic tags.
    """
    # Initialize an empty list to store topic tags
    topic_tags = []

    # Find all elements with the specified class using BeautifulSoup
    topic_tag_elements = page_source.find_all('a',
                 class_='no-underline hover:text-current relative inline-flex items-center justify-center text-caption px-2 py-1 gap-1 rounded-full bg-fill-secondary text-text-secondary') 

    # Extract text content from each topic tag element and append to the list
    for topic_tag_element in topic_tag_elements:
        topic_tag = topic_tag_element.text
        topic_tags.append(topic_tag)

    # Join the list of topic tags into a comma-separated string
    topic_tags_str = ', '.join(f"'{item}'" for item in topic_tags)

    # Return the formatted string of topic tags
    return topic_tags_str

# %% [markdown]
# 4. `get_accepted(page_source)`:
#    - Extracts the number of accepted submissions from the given page source.

# %%
def get_accepted(page_source):
    """
    Extracts the number of accepted submissions from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        Tag: The BeautifulSoup Tag object containing the information about accepted submissions.
    """
    # Find all elements with the specified class using BeautifulSoup
    accepted_elements = page_source.find_all('div', class_='text-label-1 dark:text-dark-label-1 text-sm font-medium')

    # Return the first element (it contains the information about accepted submissions)
    return accepted_elements[0]

# %% [markdown]
# 5. `get_submission(page_source)`:
#    - Extracts the number of total submissions from the given page source.

# %%
def get_submission(page_source):
    """
    Extracts the number of total submissions from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        Tag: The BeautifulSoup Tag object containing the information about total submissions.
    """
    # Find all elements with the specified class using BeautifulSoup
    submission_elements = page_source.find_all('div', class_='text-label-1 dark:text-dark-label-1 text-sm font-medium')

    # Return the second element (it contains the information about total submissions)
    return submission_elements[1]

# %% [markdown]
# 6. `get_solution(page_source)`:
#    - Extracts the solution count from the given page source.

# %%
def get_solution(page_source):
    """
    Extracts the solution count from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: The extracted solution.
    """
    # Find the element with a link containing 'solutions' using BeautifulSoup
    solutions_element = page_source.find(href=re.compile("solutions"))

    # Use regular expression to extract the solution type from the text
    solution = re.findall(r"\((.*?)\)", solutions_element.text)[0]

    # Return the extracted solution count
    return solution

# %% [markdown]
# 7. `get_discussion_count(page_source)`:
#    - Extracts the count of discussions from the given page source.

# %%
def get_discussion_count(page_source):
    """
    Extracts the count of discussions from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: The extracted count of discussions.
    """
    # Find the element with the specified class using BeautifulSoup
    # discussions_element = page_source.find_all('div', string=re.compile(r'\b\d+\.\d+K\b', re.IGNORECASE))
    value = '0'
    relative_divs = page_source.find_all('div', class_="relative text-[14px] leading-[normal] p-[1px] before:block before:h-3.5 before:w-3.5")

    # Loop through the found divs to get their next sibling with class=""
    counter = 0
    for relative_div in relative_divs:
        next_sibling = relative_div.find_next_sibling('div', class_="")
        if next_sibling:
            counter += 1
            if counter == 2:
                value = next_sibling.text.strip()
                break
    # counter = 0
    # for match in discussions_element:
    #     if match.get('class') == []:  # Check if class attribute is an empty list (equivalent to class="")
    #         counter += 1
    #         # print(match.text.strip(), 'hereeee')
    #         if counter == 2:
    #             print(match.text.strip(), 'hereeee')
    #             value = match.text.strip()  # Extract the text content and break
    #             break
    # Return the extracted count of discussions
    return value

# %% [markdown]
# 8. `get_likes(page_source)`:
#    - Extracts the number of likes from the given page source.

# %%
def get_likes(page_source):
    """
    Extracts the number of likes from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: The extracted number of likes.
    """
    # Find the element with the specified class using BeautifulSoup
    # likes_element = page_source.find_all('div', string=re.compile(r'\b\d+\.\d+K\b', re.IGNORECASE))
    relative_divs = page_source.find_all('div', class_="relative text-[14px] leading-[normal] p-[1px] before:block before:h-3.5 before:w-3.5")
    value = '0'
    # for match in likes_element:
    #     if match.get('class') == []:  # Check if class attribute is an empty list (equivalent to class="")
    #         # print(match.text.strip(), 'hereeee')
    #         value = match.text.strip()  # Extract the text content and break
    #         break
    # counter = 0
    for relative_div in relative_divs:
        next_sibling = relative_div.find_next_sibling('div', class_="")
        if next_sibling:
            # counter += 1
            # if counter == 1:
            value = next_sibling.text.strip()
            break
    # print(value)
    # Return the extracted number of likes
    return value

# %% [markdown]
# 9. `get_dislikes(page_source)`:
#    - Extracts the number of dislikes from the given page source.

# %%
def get_dislikes(page_source):
    """
    Extracts the number of dislikes from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: The extracted number of dislikes.
    """
    # Find the element with the specified class using BeautifulSoup
    dislikes_element = page_source.find_all('div', class_='text-lg text-gray-6 dark:text-dark-gray-6')[1]

    # Find the next sibling element and extract the text content
    dislikes_count = dislikes_element.find_next_sibling().text

    # Return the extracted number of dislikes
    return dislikes_count

# %% [markdown]
# 10. `get_similar_questions(page_source)`:
#     - Extracts a list of similar questions from the given page source.

# %%
def get_similar_questions(page_source):
    """
    Extracts a list of similar questions from the given page source.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: Comma-separated string of extracted similar questions.
    """
    # Initialize an empty list to store similar questions
    similar_questions = []

    # Find all elements with the specified class using BeautifulSoup
    similar_question_elements = page_source.find_all('a', class_='text-sm font-medium transition-none text-label-1 dark:text-dark-label-1 hover:text-blue-s dark:hover:text-dark-blue-s')

    # Extract text content from each similar question element and append to the list
    for similar_question_element in similar_question_elements:
        similar_question = similar_question_element.text
        similar_questions.append(similar_question)

    # Join the list of similar questions into a comma-separated string
    similar_questions_str = ', '.join(f"'{item}'" for item in similar_questions)

    # Return the formatted string of similar questions
    return similar_questions_str

# %% [markdown]
# 11. `get_page_source(url, delay=10)`:
#     - Retrieves the page source of a specified URL using Selenium and BeautifulSoup.

# %%
def get_page_source(driver, url, delay=10):
    """
    Retrieves the page source of a specified URL using Selenium and BeautifulSoup.

    Args:
        driver (webdriver): The Selenium WebDriver object.
        url (str): The URL to scrape.
        delay (int, optional): Delay in seconds to wait for the page to load. Default is 10 seconds.

    Returns:
        BeautifulSoup: The BeautifulSoup object representing the page source.
    """
    
    # Open the specified URL in the browser
    driver.get(url)

    # Allow time for the page to load (adjust delay as needed)
    time.sleep(delay)

    # Get the page source using BeautifulSoup for parsing
    page_source = BeautifulSoup(driver.page_source, 'html.parser')

    # Return the parsed page source
    return page_source

# %% [markdown]
# 12. `get_ispremium(page_source)`:
#     - Checks if the page indicates a premium status.

# %%
def get_is_premium(page_source):
    """
    Checks if the page indicates a premium status.

    Args:
        page_source (BeautifulSoup): The BeautifulSoup object representing the page source.

    Returns:
        str: 'True' if premium, 'False' otherwise.
    """
    # Find the element with the specified class using BeautifulSoup
    premium_element = page_source.find('div', class_='text-md mb-6 text-center text-label-2 dark:text-dark-label-2')

    # Determine premium status based on the existence of the element
    is_premium = 'True' if premium_element else 'False'

    # Return the premium status
    return is_premium

# %% [markdown]
# 13. `scrape(df1, start=1, end=3000, file_name='x2.csv')`:
#     - Scrapes data for a range of links from the provided DataFrame and saves it to a CSV file.

# %%
def scrape(df1, start=1, end=3000, file_name='x2.csv'):
    """
    Scrapes data for a range of links from the provided DataFrame and saves it to a CSV file.

    Args:
        df1 (DataFrame): The DataFrame containing problem URLs.
        start (int, optional): The starting index for scraping. Default is 1.
        end (int, optional): The ending index for scraping. Default is 3000.
        file_name (str, optional): The name of the CSV file to save the scraped data. Default is 'x2.csv'.
    """
    # Extract links for the specified range from the DataFrame
    links = df1['problem_URL'][start - 1:end]

    # Initialize an empty list to store DataFrames for each link
    dfs = []
    
    # Set the path to the ChromeDriver executable
    service = Service('/opt/homebrew/bin/chromedriver')

    # Configure Chrome options
    options = webdriver.ChromeOptions()
    options.add_argument('--ignore-certificate-errors')  # Ignore certificate errors
    options.add_argument('--start-maximized')  # Start the browser in maximized mode

    # Create a Chrome WebDriver instance with the specified service and options
    driver = webdriver.Chrome(service=service, options=options)

    # Iterate over the links and scrape data
    counter = 0
    for link in links:
        i = 0
        # Get the page source for the current link
        page_source = get_page_source(driver, link, delay=10)
        # print(page_source)
        # Create a dictionary to store scraped data
        data = {'is_premium': get_is_premium(page_source)}

        # Check if the problem is not premium before scraping additional data
        if data['is_premium'] == 'False':
            # Update the data dictionary with additional scraped data
            data.update({
                'title': get_title(page_source),
                'problem_description': get_problem_description(page_source),
                'topic_tags': get_topic_tags(page_source),
                'accepted': get_accepted(page_source),
                'submission': get_submission(page_source),
                # 'solution': get_solution(page_source),
                'discussion_count': get_discussion_count(page_source),
                'likes': get_likes(page_source),
                # 'dislikes': get_dislikes(page_source),
                'similar_questions': get_similar_questions(page_source)
            })

            # Create a DataFrame for the current link and append it to the list
            df = pd.DataFrame(data, index=[i])
            print("Current count ", counter)
            dfs.append(df)
            i += 1
            counter += 1
    print(dfs)
    # Concatenate the list of DataFrames into a single DataFrame
    df = pd.concat(dfs, ignore_index=True)

    # Save the final DataFrame to a CSV file
    df.to_csv(path_or_buf=file_name, index=None)

# %%
scrape(df1, start=1, end=3000, file_name='x2.csv')
# Out:
# Current count  0
# Current count  1
# Current count  2
# Current count  3
# Current count  4
# Current count  5
# Current count  6
# Current count  7
# Current count  8
# Current count  9
# Current count  10
# Current count  11
# Current count  12
# Current count  13
# Current count  14
# Current count  15
# Current count  16
# Current count  17
# Current count  18
# Current count  19
# Current count  20
# Current count  21
# Current count  22
# Current count  23
# Current count  24
# Current count  25
# Current count  26
# Current count  27
# Current count  28
# Current count  29
# Current count  30
# Current count  31
# Current count  32
# Current count  33
# Current count  34
# Current count  35
# Current count  36
# Current count  37
# Current count  38
# Current count  39
# Current count  40
# Current count  41
# Current count  42
# Current count  43
# Current count  44
# Current count  45
# Current count  46
# Current count  47
# Current count  48
# Current count  49
# Current count  50
# Current count  51
# Current count  52
# Current count  53
# Current count  54
# Current count  55
# Current count  56
# Current count  57
# Current count  58
# Current count  59
# Current count  60
# Current count  61
# Current count  62
# Current count  63
# Current count  64
# Current count  65
# Current count  66
# Current count  67
# Current count  68
# Current count  69
# Current count  70
# Current count  71
# Current count  72
# Current count  73
# Current count  74
# Current count  75
# Current count  76
# Current count  77
# Current count  78
# Current count  79
# Current count  80
# Current count  81
# Current count  82
# Current count  83
# Current count  84
# Current count  85
# Current count  86
# Current count  87
# Current count  88
# Current count  89
# Current count  90
# Current count  91
# Current count  92
# Current count  93
# Current count  94
# Current count  95
# Current count  96
# Current count  97
# Current count  98
# Current count  99
# Current count  100
# Current count  101
# Current count  102
# Current count  103
# Current count  104
# Current count  105
# Current count  106
# Current count  107
# Current count  108
# Current count  109
# Current count  110
# Current count  111
# Current count  112
# Current count  113
# Current count  114
# Current count  115
# Current count  116
# Current count  117
# Current count  118
# Current count  119
# Current count  120
# Current count  121
# Current count  122
# Current count  123
# Current count  124
# Current count  125
# Current count  126
# Current count  127
# Current count  128
# Current count  129
# Current count  130
# Current count  131
# Current count  132
# Current count  133
# Current count  134
# Current count  135
# Current count  136
# Current count  137
# Current count  138
# Current count  139
# Current count  140
# Current count  141
# Current count  142
# Current count  143
# Current count  144
# Current count  145
# Current count  146
# Current count  147
# Current count  148
# Current count  149
# Current count  150
# Current count  151
# Current count  152
# Current count  153
# Current count  154
# Current count  155
# Current count  156
# Current count  157
# Current count  158
# Current count  159
# Current count  160
# Current count  161
# Current count  162
# Current count  163
# Current count  164
# Current count  165
# Current count  166
# Current count  167
# Current count  168
# Current count  169
# Current count  170
# Current count  171
# Current count  172
# Current count  173
# Current count  174
# Current count  175
# Current count  176
# Current count  177
# Current count  178
# Current count  179
# Current count  180
# Current count  181
# Current count  182
# Current count  183
# Current count  184
# Current count  185
# Current count  186
# Current count  187
# Current count  188
# Current count  189
# Current count  190
# Current count  191
# Current count  192
# Current count  193
# Current count  194
# Current count  195
# Current count  196
# Current count  197
# Current count  198
# Current count  199
# Current count  200
# Current count  201
# Current count  202
# Current count  203
# Current count  204
# Current count  205
# Current count  206
# Current count  207
# Current count  208
# Current count  209
# Current count  210
# Current count  211
# Current count  212
# Current count  213
# Current count  214
# Current count  215
# Current count  216
# Current count  217
# Current count  218
# Current count  219
# Current count  220
# Current count  221
# Current count  222
# Current count  223
# Current count  224
# Current count  225
# Current count  226
# Current count  227
# Current count  228
# Current count  229
# Current count  230
# Current count  231
# Current count  232
# Current count  233
# Current count  234
# Current count  235
# Current count  236
# Current count  237
# Current count  238
# Current count  239
# Current count  240
# Current count  241
# Current count  242
# Current count  243
# Current count  244
# Current count  245
# Current count  246
# Current count  247
# Current count  248
# Current count  249
# Current count  250
# Current count  251
# Current count  252
# Current count  253
# Current count  254
# Current count  255
# Current count  256
# Current count  257
# Current count  258
# Current count  259
# Current count  260
# Current count  261
# Current count  262
# Current count  263
# Current count  264
# Current count  265
# Current count  266
# Current count  267
# Current count  268
# Current count  269
# Current count  270
# Current count  271
# Current count  272
# Current count  273
# Current count  274
# Current count  275
# Current count  276
# Current count  277
# Current count  278
# Current count  279
# Current count  280
# Current count  281
# Current count  282
# Current count  283
# Current count  284
# Current count  285
# Current count  286
# Current count  287
# Current count  288
# Current count  289
# Current count  290
# Current count  291
# Current count  292
# Current count  293
# Current count  294
# Current count  295
# Current count  296
# Current count  297
# Current count  298
# Current count  299
# Current count  300
# Current count  301
# Current count  302
# Current count  303
# Current count  304
# Current count  305
# Current count  306
# Current count  307
# Current count  308
# Current count  309
# Current count  310
# Current count  311
# Current count  312
# Current count  313
# Current count  314
# Current count  315
# Current count  316
# Current count  317
# Current count  318
# Current count  319
# Current count  320
# Current count  321
# Current count  322
# Current count  323
# Current count  324
# Current count  325
# Current count  326
# Current count  327
# Current count  328
# Current count  329
# Current count  330
# Current count  331
# Current count  332
# Current count  333
# Current count  334
# Current count  335
# Current count  336
# Current count  337
# Current count  338
# Current count  339
# Current count  340
# Current count  341
# Current count  342
# Current count  343
# Current count  344
# Current count  345
# Current count  346
# Current count  347
# Current count  348
# Current count  349
# Current count  350
# Current count  351
# Current count  352
# Current count  353
# Current count  354
# Current count  355
# Current count  356
# Current count  357
# Current count  358
# Current count  359
# Current count  360
# Current count  361
# Current count  362
# Current count  363
# Current count  364
# Current count  365
# Current count  366
# Current count  367
# Current count  368
# Current count  369
# Current count  370
# Current count  371
# Current count  372
# Current count  373
# Current count  374
# Current count  375
# Current count  376
# Current count  377
# Current count  378
# Current count  379
# Current count  380
# Current count  381
# Current count  382
# Current count  383
# Current count  384
# Current count  385
# Current count  386
# Current count  387
# Current count  388
# Current count  389
# Current count  390
# Current count  391
# Current count  392
# Current count  393
# Current count  394
# Current count  395
# Current count  396
# Current count  397
# Current count  398
# Current count  399
# Current count  400
# Current count  401
# Current count  402
# Current count  403
# Current count  404
# Current count  405
# Current count  406
# Current count  407
# Current count  408
# Current count  409
# Current count  410
# Current count  411
# Current count  412
# Current count  413
# Current count  414
# Current count  415
# Current count  416
# Current count  417
# Current count  418
# Current count  419
# Current count  420
# Current count  421
# Current count  422
# Current count  423
# Current count  424
# Current count  425
# Current count  426
# Current count  427
# Current count  428
# Current count  429
# Current count  430
# Current count  431
# Current count  432
# Current count  433
# Current count  434
# Current count  435
# Current count  436
# Current count  437
# Current count  438
# Current count  439
# Current count  440
# Current count  441
# Current count  442
# Current count  443
# Current count  444
# Current count  445
# Current count  446
# Current count  447
# Current count  448
# Current count  449
# Current count  450
# Current count  451
# Current count  452
# Current count  453
# Current count  454
# Current count  455
# Current count  456
# Current count  457
# Current count  458
# Current count  459
# Current count  460
# Current count  461
# Current count  462
# Current count  463
# Current count  464
# Current count  465
# Current count  466
# Current count  467
# Current count  468
# Current count  469
# Current count  470
# Current count  471
# Current count  472
# Current count  473
# Current count  474
# Current count  475
# Current count  476
# Current count  477
# Current count  478
# Current count  479
# Current count  480
# Current count  481
# Current count  482
# Current count  483
# Current count  484
# Current count  485
# Current count  486
# Current count  487
# Current count  488
# Current count  489
# Current count  490
# Current count  491
# Current count  492
# Current count  493
# Current count  494
# Current count  495
# Current count  496
# Current count  497
# Current count  498
# Current count  499
# Current count  500
# Current count  501
# Current count  502
# Current count  503
# Current count  504
# Current count  505
# Current count  506
# Current count  507
# Current count  508
# Current count  509
# Current count  510
# Current count  511
# Current count  512
# Current count  513
# Current count  514
# Current count  515
# Current count  516
# Current count  517
# Current count  518
# Current count  519
# Current count  520
# Current count  521
# Current count  522
# Current count  523
# Current count  524
# Current count  525
# Current count  526
# Current count  527
# Current count  528
# Current count  529
# Current count  530
# Current count  531
# Current count  532
# Current count  533
# Current count  534
# Current count  535
# Current count  536
# Current count  537
# Current count  538
# Current count  539
# Current count  540
# Current count  541
# Current count  542
# Current count  543
# Current count  544
# Current count  545
# Current count  546
# Current count  547
# Current count  548
# Current count  549
# Current count  550
# Current count  551
# Current count  552
# Current count  553
# Current count  554
# Current count  555
# Current count  556
# Current count  557
# Current count  558
# Current count  559
# Current count  560
# Current count  561
# Current count  562
# Current count  563
# Current count  564
# Current count  565
# Current count  566
# Current count  567
# Current count  568
# Current count  569
# Current count  570
# Current count  571
# Current count  572
# Current count  573
# Current count  574
# Current count  575
# Current count  576
# Current count  577
# Current count  578
# Current count  579
# Current count  580
# Current count  581
# Current count  582
# Current count  583
# Current count  584
# Current count  585
# Current count  586
# Current count  587
# Current count  588
# Current count  589
# Current count  590
# Current count  591
# Current count  592
# Current count  593
# Current count  594
# Current count  595
# Current count  596
# Current count  597
# Current count  598
# Current count  599
# Current count  600
# Current count  601
# Current count  602
# Current count  603
# Current count  604
# Current count  605
# Current count  606
# Current count  607
# Current count  608
# Current count  609
# Current count  610
# Current count  611
# Current count  612
# Current count  613
# Current count  614
# Current count  615
# Current count  616
# Current count  617
# Current count  618
# Current count  619
# Current count  620
# Current count  621
# Current count  622
# Current count  623
# Current count  624
# Current count  625
# Current count  626
# Current count  627
# Current count  628
# Current count  629
# Current count  630
# Current count  631
# Current count  632
# Current count  633
# Current count  634
# Current count  635
# Current count  636
# Current count  637
# Current count  638
# Current count  639
# Current count  640
# Current count  641
# Current count  642
# Current count  643
# Current count  644
# Current count  645
# Current count  646
# Current count  647
# Current count  648
# Current count  649
# Current count  650
# Current count  651
# Current count  652
# Current count  653
# Current count  654
# Current count  655
# Current count  656
# Current count  657
# Current count  658
# Current count  659
# Current count  660
# Current count  661
# Current count  662
# Current count  663
# Current count  664
# Current count  665
# Current count  666
# Current count  667
# Current count  668
# Current count  669
# Current count  670
# Current count  671
# Current count  672
# Current count  673
# Current count  674
# Current count  675
# Current count  676
# Current count  677
# Current count  678
# Current count  679
# Current count  680
# Current count  681
# Current count  682
# Current count  683
# Current count  684
# Current count  685
# Current count  686
# Current count  687
# Current count  688
# Current count  689
# Current count  690
# Current count  691
# Current count  692
# Current count  693
# Current count  694
# Current count  695
# Current count  696
# Current count  697
# Current count  698
# Current count  699
# Current count  700
# Current count  701
# Current count  702
# Current count  703
# Current count  704
# Current count  705
# Current count  706
# Current count  707
# Current count  708
# Current count  709
# Current count  710
# Current count  711
# Current count  712
# Current count  713
# Current count  714
# Current count  715
# Current count  716
# Current count  717
# Current count  718
# Current count  719
# Current count  720
# Current count  721
# Current count  722
# Current count  723
# Current count  724
# Current count  725
# Current count  726
# Current count  727
# Current count  728
# Current count  729
# Current count  730
# Current count  731
# Current count  732
# Current count  733
# Current count  734
# Current count  735
# Current count  736
# Current count  737
# Current count  738
# Current count  739
# Current count  740
# Current count  741
# Current count  742
# Current count  743
# Current count  744
# Current count  745
# Current count  746
# Current count  747
# Current count  748
# Current count  749
# Current count  750
# Current count  751
# Current count  752
# Current count  753
# Current count  754
# Current count  755
# Current count  756
# Current count  757
# Current count  758
# Current count  759
# Current count  760
# Current count  761
# Current count  762
# Current count  763
# Current count  764
# Current count  765
# Current count  766
# Current count  767
# Current count  768
# Current count  769
# Current count  770
# Current count  771
# Current count  772
# Current count  773
# Current count  774
# Current count  775
# Current count  776
# Current count  777
# Current count  778
# Current count  779
# Current count  780
# Current count  781
# Current count  782
# Current count  783
# Current count  784
# Current count  785
# Current count  786
# Current count  787
# Current count  788
# Current count  789
# Current count  790
# Current count  791
# Current count  792
# Current count  793
# Current count  794
# Current count  795
# Current count  796
# Current count  797
# Current count  798
# Current count  799
# Current count  800
# Current count  801
# Current count  802
# Current count  803
# Current count  804
# Current count  805
# Current count  806
# Current count  807
# Current count  808
# Current count  809
# Current count  810
# Current count  811
# Current count  812
# Current count  813
# Current count  814
# Current count  815
# Current count  816
# Current count  817
# Current count  818
# Current count  819
# Current count  820
# Current count  821
# Current count  822
# Current count  823
# Current count  824
# Current count  825
# Current count  826
# Current count  827
# Current count  828
# Current count  829
# Current count  830
# Current count  831
# Current count  832
# Current count  833
# Current count  834
# Current count  835
# Current count  836
# Current count  837
# Current count  838
# Current count  839
# Current count  840
# Current count  841
# Current count  842
# Current count  843
# Current count  844
# Current count  845
# Current count  846
# Current count  847
# Current count  848
# Current count  849
# Current count  850
# Current count  851
# Current count  852
# Current count  853
# Current count  854
# Current count  855
# Current count  856
# Current count  857
# Current count  858
# Current count  859
# Current count  860
# Current count  861
# Current count  862
# Current count  863
# Current count  864
# Current count  865
# Current count  866
# Current count  867
# Current count  868
# Current count  869
# Current count  870
# Current count  871
# Current count  872
# Current count  873
# Current count  874
# Current count  875
# Current count  876
# Current count  877
# Current count  878
# Current count  879
# Current count  880
# Current count  881
# Current count  882
# Current count  883
# Current count  884
# Current count  885
# Current count  886
# Current count  887
# Current count  888
# Current count  889
# Current count  890
# Current count  891
# Current count  892
# Current count  893
# Current count  894
# Current count  895
# Current count  896
# Current count  897
# Current count  898
# Current count  899
# Current count  900
# Current count  901
# Current count  902
# Current count  903
# Current count  904
# Current count  905
# Current count  906
# Current count  907
# Current count  908
# Current count  909
# Current count  910
# Current count  911
# Current count  912
# Current count  913
# Current count  914
# Current count  915
# Current count  916
# Current count  917
# Current count  918
# Current count  919
# Current count  920
# Current count  921
# Current count  922
# Current count  923
# Current count  924
# Current count  925
# Current count  926
# Current count  927
# Current count  928
# Current count  929
# Current count  930
# Current count  931
# Current count  932
# Current count  933
# Current count  934
# Current count  935
# Current count  936
# Current count  937
# Current count  938
# Current count  939
# Current count  940
# Current count  941
# Current count  942
# Current count  943
# Current count  944
# Current count  945
# Current count  946
# Current count  947
# Current count  948
# Current count  949
# Current count  950
# Current count  951
# Current count  952
# Current count  953
# Current count  954
# Current count  955
# Current count  956
# Current count  957
# Current count  958
# Current count  959
# Current count  960
# Current count  961
# Current count  962
# Current count  963
# Current count  964
# Current count  965
# Current count  966
# Current count  967
# Current count  968
# Current count  969
# Current count  970
# Current count  971
# Current count  972
# Current count  973
# Current count  974
# Current count  975
# Current count  976
# Current count  977
# Current count  978
# Current count  979
# Current count  980
# Current count  981
# Current count  982
# Current count  983
# Current count  984
# Current count  985
# Current count  986
# Current count  987
# Current count  988
# Current count  989
# Current count  990
# Current count  991
# Current count  992
# Current count  993
# Current count  994
# Current count  995
# Current count  996
# Current count  997
# Current count  998
# Current count  999
# Current count  1000
# Current count  1001
# Current count  1002
# Current count  1003
# Current count  1004
# Current count  1005
# Current count  1006
# Current count  1007
# Current count  1008
# Current count  1009
# Current count  1010
# Current count  1011
# Current count  1012
# Current count  1013
# Current count  1014
# Current count  1015
# Current count  1016
# Current count  1017
# Current count  1018
# Current count  1019
# Current count  1020
# Current count  1021
# Current count  1022
# Current count  1023
# Current count  1024
# Current count  1025
# Current count  1026
# Current count  1027
# Current count  1028
# Current count  1029
# Current count  1030
# Current count  1031
# Current count  1032
# Current count  1033
# Current count  1034
# Current count  1035
# Current count  1036
# Current count  1037
# Current count  1038
# Current count  1039
# Current count  1040
# Current count  1041
# Current count  1042
# Current count  1043
# Current count  1044
# Current count  1045
# Current count  1046
# Current count  1047
# Current count  1048
# Current count  1049
# Current count  1050
# Current count  1051
# Current count  1052
# Current count  1053
# Current count  1054
# Current count  1055
# Current count  1056
# Current count  1057
# Current count  1058
# Current count  1059
# Current count  1060
# Current count  1061
# Current count  1062
# Current count  1063
# Current count  1064
# Current count  1065
# Current count  1066
# Current count  1067
# Current count  1068
# Current count  1069
# Current count  1070
# Current count  1071
# Current count  1072
# Current count  1073
# Current count  1074
# Current count  1075
# Current count  1076
# Current count  1077
# Current count  1078
# Current count  1079
# Current count  1080
# Current count  1081
# Current count  1082
# Current count  1083
# Current count  1084
# Current count  1085
# Current count  1086
# Current count  1087
# Current count  1088
# Current count  1089
# Current count  1090
# Current count  1091
# Current count  1092
# Current count  1093
# Current count  1094
# Current count  1095
# Current count  1096
# Current count  1097
# Current count  1098
# Current count  1099
# Current count  1100
# Current count  1101
# Current count  1102
# Current count  1103
# Current count  1104
# Current count  1105
# Current count  1106
# Current count  1107
# Current count  1108
# Current count  1109
# Current count  1110
# Current count  1111
# Current count  1112
# Current count  1113
# Current count  1114
# Current count  1115
# Current count  1116
# Current count  1117
# Current count  1118
# Current count  1119
# Current count  1120
# Current count  1121
# Current count  1122
# Current count  1123
# Current count  1124
# Current count  1125
# Current count  1126
# Current count  1127
# Current count  1128
# Current count  1129
# Current count  1130
# Current count  1131
# Current count  1132
# Current count  1133
# Current count  1134
# Current count  1135
# Current count  1136
# Current count  1137
# Current count  1138
# Current count  1139
# Current count  1140
# Current count  1141
# Current count  1142
# Current count  1143
# Current count  1144
# Current count  1145
# Current count  1146
# Current count  1147
# Current count  1148
# Current count  1149
# Current count  1150
# Current count  1151
# Current count  1152
# Current count  1153
# Current count  1154
# Current count  1155
# Current count  1156
# Current count  1157
# Current count  1158
# Current count  1159
# Current count  1160
# Current count  1161
# Current count  1162
# Current count  1163
# Current count  1164
# Current count  1165
# Current count  1166
# Current count  1167
# Current count  1168
# Current count  1169
# Current count  1170
# Current count  1171
# Current count  1172
# Current count  1173
# Current count  1174
# Current count  1175
# Current count  1176
# Current count  1177
# Current count  1178
# Current count  1179
# Current count  1180
# Current count  1181
# Current count  1182
# Current count  1183
# Current count  1184
# Current count  1185
# Current count  1186
# Current count  1187
# Current count  1188
# Current count  1189
# Current count  1190
# Current count  1191
# Current count  1192
# Current count  1193
# Current count  1194
# Current count  1195
# Current count  1196
# Current count  1197
# Current count  1198
# Current count  1199
# Current count  1200
# Current count  1201
# Current count  1202
# Current count  1203
# Current count  1204
# Current count  1205
# Current count  1206
# Current count  1207
# Current count  1208
# Current count  1209
# Current count  1210
# Current count  1211
# Current count  1212
# Current count  1213
# Current count  1214
# Current count  1215
# Current count  1216
# Current count  1217
# Current count  1218
# Current count  1219
# Current count  1220
# Current count  1221
# Current count  1222
# Current count  1223
# Current count  1224
# Current count  1225
# Current count  1226
# Current count  1227
# Current count  1228
# Current count  1229
# Current count  1230
# Current count  1231
# Current count  1232
# Current count  1233
# Current count  1234
# Current count  1235
# Current count  1236
# Current count  1237
# Current count  1238
# Current count  1239
# Current count  1240
# Current count  1241
# Current count  1242
# Current count  1243
# Current count  1244
# Current count  1245
# Current count  1246
# Current count  1247
# Current count  1248
# Current count  1249
# Current count  1250
# Current count  1251
# Current count  1252
# Current count  1253
# Current count  1254
# Current count  1255
# Current count  1256
# Current count  1257
# Current count  1258
# Current count  1259
# Current count  1260
# Current count  1261
# Current count  1262
# Current count  1263
# Current count  1264
# Current count  1265
# Current count  1266
# Current count  1267
# Current count  1268
# Current count  1269
# Current count  1270
# Current count  1271
# Current count  1272
# Current count  1273
# Current count  1274
# Current count  1275
# Current count  1276
# Current count  1277
# Current count  1278
# Current count  1279
# Current count  1280
# Current count  1281
# Current count  1282
# Current count  1283
# Current count  1284
# Current count  1285
# Current count  1286
# Current count  1287
# Current count  1288
# Current count  1289
# Current count  1290
# Current count  1291
# Current count  1292
# Current count  1293
# Current count  1294
# Current count  1295
# Current count  1296
# Current count  1297
# Current count  1298
# Current count  1299
# Current count  1300
# Current count  1301
# Current count  1302
# Current count  1303
# Current count  1304
# Current count  1305
# Current count  1306
# Current count  1307
# Current count  1308
# Current count  1309
# Current count  1310
# Current count  1311
# Current count  1312
# Current count  1313
# Current count  1314
# Current count  1315
# Current count  1316
# Current count  1317
# Current count  1318
# Current count  1319
# Current count  1320
# Current count  1321
# Current count  1322
# Current count  1323
# Current count  1324
# Current count  1325
# Current count  1326
# Current count  1327
# Current count  1328
# Current count  1329
# Current count  1330
# Current count  1331
# Current count  1332
# Current count  1333
# Current count  1334
# Current count  1335
# Current count  1336
# Current count  1337
# Current count  1338
# Current count  1339
# Current count  1340
# Current count  1341
# Current count  1342
# Current count  1343
# Current count  1344
# Current count  1345
# Current count  1346
# Current count  1347
# Current count  1348
# Current count  1349
# Current count  1350
# Current count  1351
# Current count  1352
# Current count  1353
# Current count  1354
# Current count  1355
# Current count  1356
# Current count  1357
# Current count  1358
# Current count  1359
# Current count  1360
# Current count  1361
# Current count  1362
# Current count  1363
# Current count  1364
# Current count  1365
# Current count  1366
# Current count  1367
# Current count  1368
# Current count  1369
# Current count  1370
# Current count  1371
# Current count  1372
# Current count  1373
# Current count  1374
# Current count  1375
# Current count  1376
# Current count  1377
# Current count  1378
# Current count  1379
# Current count  1380
# Current count  1381
# Current count  1382
# Current count  1383
# Current count  1384
# Current count  1385
# Current count  1386
# Current count  1387
# Current count  1388
# Current count  1389
# Current count  1390
# Current count  1391
# Current count  1392
# Current count  1393
# Current count  1394
# Current count  1395
# Current count  1396
# Current count  1397
# Current count  1398
# Current count  1399
# Current count  1400
# Current count  1401
# Current count  1402
# Current count  1403
# Current count  1404
# Current count  1405
# Current count  1406
# Current count  1407
# Current count  1408
# Current count  1409
# Current count  1410
# Current count  1411
# Current count  1412
# Current count  1413
# Current count  1414
# Current count  1415
# Current count  1416
# Current count  1417
# Current count  1418
# Current count  1419
# Current count  1420
# Current count  1421
# Current count  1422
# Current count  1423
# Current count  1424
# Current count  1425
# Current count  1426
# Current count  1427
# Current count  1428
# Current count  1429
# Current count  1430
# Current count  1431
# Current count  1432
# Current count  1433
# Current count  1434
# Current count  1435
# Current count  1436
# Current count  1437
# Current count  1438
# Current count  1439
# Current count  1440
# Current count  1441
# Current count  1442
# Current count  1443
# Current count  1444
# Current count  1445
# Current count  1446
# Current count  1447
# Current count  1448
# Current count  1449
# Current count  1450
# Current count  1451
# Current count  1452
# Current count  1453
# Current count  1454
# Current count  1455
# Current count  1456
# Current count  1457
# Current count  1458
# Current count  1459
# Current count  1460
# Current count  1461
# Current count  1462
# Current count  1463
# Current count  1464
# Current count  1465
# Current count  1466
# Current count  1467
# Current count  1468
# Current count  1469
# Current count  1470
# Current count  1471
# Current count  1472
# Current count  1473
# Current count  1474
# Current count  1475
# Current count  1476
# Current count  1477
# Current count  1478
# Current count  1479
# Current count  1480
# Current count  1481
# Current count  1482
# Current count  1483
# Current count  1484
# Current count  1485
# Current count  1486
# Current count  1487
# Current count  1488
# Current count  1489
# Current count  1490
# Current count  1491
# Current count  1492
# Current count  1493
# Current count  1494
# Current count  1495
# Current count  1496
# Current count  1497
# Current count  1498
# Current count  1499
# Current count  1500
# Current count  1501
# Current count  1502
# Current count  1503
# Current count  1504
# Current count  1505
# Current count  1506
# Current count  1507
# Current count  1508
# Current count  1509
# Current count  1510
# Current count  1511
# Current count  1512
# Current count  1513
# Current count  1514
# Current count  1515
# Current count  1516
# Current count  1517
# Current count  1518
# Current count  1519
# Current count  1520
# Current count  1521
# Current count  1522
# Current count  1523
# Current count  1524
# Current count  1525
# Current count  1526
# Current count  1527
# Current count  1528
# Current count  1529
# Current count  1530
# Current count  1531
# Current count  1532
# Current count  1533
# Current count  1534
# Current count  1535
# Current count  1536
# Current count  1537
# Current count  1538
# Current count  1539
# Current count  1540
# Current count  1541
# Current count  1542
# Current count  1543
# Current count  1544
# Current count  1545
# Current count  1546
# Current count  1547
# Current count  1548
# Current count  1549
# Current count  1550
# Current count  1551
# Current count  1552
# Current count  1553
# Current count  1554
# Current count  1555
# Current count  1556
# Current count  1557
# Current count  1558
# Current count  1559
# Current count  1560
# Current count  1561
# Current count  1562
# Current count  1563
# Current count  1564
# Current count  1565
# Current count  1566
# Current count  1567
# Current count  1568
# Current count  1569
# Current count  1570
# Current count  1571
# Current count  1572
# Current count  1573
# Current count  1574
# Current count  1575
# Current count  1576
# Current count  1577
# Current count  1578
# Current count  1579
# Current count  1580
# Current count  1581
# Current count  1582
# Current count  1583
# Current count  1584
# Current count  1585
# Current count  1586
# Current count  1587
# Current count  1588
# Current count  1589
# Current count  1590
# Current count  1591
# Current count  1592
# Current count  1593
# Current count  1594
# Current count  1595
# Current count  1596
# Current count  1597
# Current count  1598
# Current count  1599
# Current count  1600
# Current count  1601
# Current count  1602
# Current count  1603
# Current count  1604
# Current count  1605
# Current count  1606
# Current count  1607
# Current count  1608
# Current count  1609
# Current count  1610
# Current count  1611
# Current count  1612
# Current count  1613
# Current count  1614
# Current count  1615
# Current count  1616
# Current count  1617
# Current count  1618
# Current count  1619
# Current count  1620
# Current count  1621
# Current count  1622
# Current count  1623
# Current count  1624
# Current count  1625
# Current count  1626
# Current count  1627
# Current count  1628
# Current count  1629
# Current count  1630
# Current count  1631
# Current count  1632
# Current count  1633
# Current count  1634
# Current count  1635
# Current count  1636
# Current count  1637
# Current count  1638
# Current count  1639
# Current count  1640
# Current count  1641
# Current count  1642
# Current count  1643
# Current count  1644
# Current count  1645
# Current count  1646
# Current count  1647
# Current count  1648
# Current count  1649
# Current count  1650
# Current count  1651
# Current count  1652
# Current count  1653
# Current count  1654
# Current count  1655
# Current count  1656
# Current count  1657
# Current count  1658
# Current count  1659
# Current count  1660
# Current count  1661
# Current count  1662
# Current count  1663
# Current count  1664
# Current count  1665
# Current count  1666
# Current count  1667
# Current count  1668
# Current count  1669
# Current count  1670
# Current count  1671
# Current count  1672
# Current count  1673
# Current count  1674
# Current count  1675
# Current count  1676
# Current count  1677
# Current count  1678
# Current count  1679
# Current count  1680
# Current count  1681
# Current count  1682
# Current count  1683
# Current count  1684
# Current count  1685
# Current count  1686
# Current count  1687
# Current count  1688
# Current count  1689
# Current count  1690
# Current count  1691
# Current count  1692
# Current count  1693
# Current count  1694
# Current count  1695
# Current count  1696
# Current count  1697
# Current count  1698
# Current count  1699
# Current count  1700
# Current count  1701
# Current count  1702
# Current count  1703
# Current count  1704
# Current count  1705
# Current count  1706
# Current count  1707
# Current count  1708
# Current count  1709
# Current count  1710
# Current count  1711
# Current count  1712
# Current count  1713
# Current count  1714
# Current count  1715
# Current count  1716
# Current count  1717
# Current count  1718
# Current count  1719
# Current count  1720
# Current count  1721
# Current count  1722
# Current count  1723
# Current count  1724
# Current count  1725
# Current count  1726
# Current count  1727
# Current count  1728
# Current count  1729
# Current count  1730
# Current count  1731
# Current count  1732
# Current count  1733
# Current count  1734
# Current count  1735
# Current count  1736
# Current count  1737
# Current count  1738
# Current count  1739
# Current count  1740
# Current count  1741
# Current count  1742
# Current count  1743
# Current count  1744
# Current count  1745
# Current count  1746
# Current count  1747
# Current count  1748
# Current count  1749
# Current count  1750
# Current count  1751
# Current count  1752
# Current count  1753
# Current count  1754
# Current count  1755
# Current count  1756
# Current count  1757
# Current count  1758
# Current count  1759
# Current count  1760
# Current count  1761
# Current count  1762
# Current count  1763
# Current count  1764
# Current count  1765
# Current count  1766
# Current count  1767
# Current count  1768
# Current count  1769
# Current count  1770
# Current count  1771
# Current count  1772
# Current count  1773
# Current count  1774
# Current count  1775
# Current count  1776
# Current count  1777
# Current count  1778
# Current count  1779
# Current count  1780
# Current count  1781
# Current count  1782
# Current count  1783
# Current count  1784
# Current count  1785
# Current count  1786
# Current count  1787
# Current count  1788
# Current count  1789
# Current count  1790
# Current count  1791
# Current count  1792
# Current count  1793
# Current count  1794
# Current count  1795
# Current count  1796
# Current count  1797
# Current count  1798
# Current count  1799
# Current count  1800
# Current count  1801
# Current count  1802
# Current count  1803
# Current count  1804
# Current count  1805
# Current count  1806
# Current count  1807
# Current count  1808
# Current count  1809
# Current count  1810
# Current count  1811
# Current count  1812
# Current count  1813
# Current count  1814
# Current count  1815
# Current count  1816
# Current count  1817
# Current count  1818
# Current count  1819
# Current count  1820
# Current count  1821
# Current count  1822
# Current count  1823
# Current count  1824
# Current count  1825
# Current count  1826
# Current count  1827
# Current count  1828
# Current count  1829
# Current count  1830
# Current count  1831
# Current count  1832
# Current count  1833
# Current count  1834
# Current count  1835
# Current count  1836
# Current count  1837
# Current count  1838
# Current count  1839
# Current count  1840
# Current count  1841
# Current count  1842
# Current count  1843
# Current count  1844
# Current count  1845
# Current count  1846
# Current count  1847
# Current count  1848
# Current count  1849
# Current count  1850
# Current count  1851
# Current count  1852
# Current count  1853
# Current count  1854
# Current count  1855
# Current count  1856
# Current count  1857
# Current count  1858
# Current count  1859
# Current count  1860
# Current count  1861
# Current count  1862
# Current count  1863
# Current count  1864
# Current count  1865
# Current count  1866
# Current count  1867
# Current count  1868
# Current count  1869
# Current count  1870
# Current count  1871
# Current count  1872
# Current count  1873
# Current count  1874
# Current count  1875
# Current count  1876
# Current count  1877
# Current count  1878
# Current count  1879
# Current count  1880
# Current count  1881
# Current count  1882
# Current count  1883
# Current count  1884
# Current count  1885
# Current count  1886
# Current count  1887
# Current count  1888
# Current count  1889
# Current count  1890
# Current count  1891
# Current count  1892
# Current count  1893
# Current count  1894
# Current count  1895
# Current count  1896
# Current count  1897
# Current count  1898
# Current count  1899
# Current count  1900
# Current count  1901
# Current count  1902
# Current count  1903
# Current count  1904
# Current count  1905
# Current count  1906
# Current count  1907
# Current count  1908
# Current count  1909
# Current count  1910
# Current count  1911
# Current count  1912
# Current count  1913
# Current count  1914
# Current count  1915
# Current count  1916
# Current count  1917
# Current count  1918
# Current count  1919
# Current count  1920
# Current count  1921
# Current count  1922
# Current count  1923
# Current count  1924
# Current count  1925
# Current count  1926
# Current count  1927
# Current count  1928
# Current count  1929
# Current count  1930
# Current count  1931
# Current count  1932
# Current count  1933
# Current count  1934
# Current count  1935
# Current count  1936
# Current count  1937
# Current count  1938
# Current count  1939
# Current count  1940
# Current count  1941
# Current count  1942
# Current count  1943
# Current count  1944
# Current count  1945
# Current count  1946
# Current count  1947
# Current count  1948
# Current count  1949
# Current count  1950
# Current count  1951
# Current count  1952
# Current count  1953
# Current count  1954
# Current count  1955
# Current count  1956
# Current count  1957
# Current count  1958
# Current count  1959
# Current count  1960
# Current count  1961
# Current count  1962
# Current count  1963
# Current count  1964
# Current count  1965
# Current count  1966
# Current count  1967
# Current count  1968
# Current count  1969
# Current count  1970
# Current count  1971
# Current count  1972
# Current count  1973
# Current count  1974
# Current count  1975
# Current count  1976
# Current count  1977
# Current count  1978
# Current count  1979
# Current count  1980
# Current count  1981
# Current count  1982
# Current count  1983
# Current count  1984
# Current count  1985
# Current count  1986
# Current count  1987
# Current count  1988
# Current count  1989
# Current count  1990
# Current count  1991
# Current count  1992
# Current count  1993
# Current count  1994
# Current count  1995
# Current count  1996
# Current count  1997
# Current count  1998
# Current count  1999
# Current count  2000
# Current count  2001
# Current count  2002
# Current count  2003
# Current count  2004
# Current count  2005
# Current count  2006
# Current count  2007
# Current count  2008
# Current count  2009
# Current count  2010
# Current count  2011
# Current count  2012
# Current count  2013
# Current count  2014
# Current count  2015
# Current count  2016
# Current count  2017
# Current count  2018
# Current count  2019
# Current count  2020
# Current count  2021
# Current count  2022
# Current count  2023
# Current count  2024
# Current count  2025
# Current count  2026
# Current count  2027
# Current count  2028
# Current count  2029
# Current count  2030
# Current count  2031
# Current count  2032
# Current count  2033
# Current count  2034
# Current count  2035
# Current count  2036
# Current count  2037
# Current count  2038
# Current count  2039
# Current count  2040
# Current count  2041
# Current count  2042
# Current count  2043
# Current count  2044
# Current count  2045
# Current count  2046
# Current count  2047
# Current count  2048
# Current count  2049
# Current count  2050
# Current count  2051
# Current count  2052
# Current count  2053
# Current count  2054
# Current count  2055
# Current count  2056
# Current count  2057
# Current count  2058
# Current count  2059
# Current count  2060
# Current count  2061
# Current count  2062
# Current count  2063
# Current count  2064
# Current count  2065
# Current count  2066
# Current count  2067
# Current count  2068
# Current count  2069
# Current count  2070
# Current count  2071
# Current count  2072
# Current count  2073
# Current count  2074
# Current count  2075
# Current count  2076
# Current count  2077
# Current count  2078
# Current count  2079
# Current count  2080
# Current count  2081
# Current count  2082
# Current count  2083
# Current count  2084
# Current count  2085
# Current count  2086
# Current count  2087
# Current count  2088
# Current count  2089
# Current count  2090
# Current count  2091
# Current count  2092
# Current count  2093
# Current count  2094
# Current count  2095
# Current count  2096
# Current count  2097
# Current count  2098
# Current count  2099
# Current count  2100
# Current count  2101
# Current count  2102
# Current count  2103
# Current count  2104
# Current count  2105
# Current count  2106
# Current count  2107
# Current count  2108
# Current count  2109
# Current count  2110
# Current count  2111
# Current count  2112
# Current count  2113
# Current count  2114
# Current count  2115
# Current count  2116
# Current count  2117
# Current count  2118
# Current count  2119
# Current count  2120
# Current count  2121
# Current count  2122
# Current count  2123
# Current count  2124
# Current count  2125
# Current count  2126
# Current count  2127
# Current count  2128
# Current count  2129
# Current count  2130
# Current count  2131
# Current count  2132
# Current count  2133
# Current count  2134
# Current count  2135
# Current count  2136
# Current count  2137
# Current count  2138
# Current count  2139
# Current count  2140
# Current count  2141
# Current count  2142
# Current count  2143
# Current count  2144
# Current count  2145
# Current count  2146
# Current count  2147
# Current count  2148
# Current count  2149
# Current count  2150
# Current count  2151
# Current count  2152
# Current count  2153
# Current count  2154
# Current count  2155
# Current count  2156
# Current count  2157
# Current count  2158
# Current count  2159
# Current count  2160
# Current count  2161
# Current count  2162
# Current count  2163
# Current count  2164
# Current count  2165
# Current count  2166
# Current count  2167
# Current count  2168
# Current count  2169
# Current count  2170
# Current count  2171
# Current count  2172
# Current count  2173
# Current count  2174
# Current count  2175
# Current count  2176
# Current count  2177
# Current count  2178
# Current count  2179
# Current count  2180
# Current count  2181
# Current count  2182
# Current count  2183
# Current count  2184
# Current count  2185
# Current count  2186
# Current count  2187
# Current count  2188
# Current count  2189
# Current count  2190
# Current count  2191
# Current count  2192
# Current count  2193
# Current count  2194
# Current count  2195
# Current count  2196
# Current count  2197
# Current count  2198
# Current count  2199
# Current count  2200
# Current count  2201
# Current count  2202
# Current count  2203
# Current count  2204
# Current count  2205
# Current count  2206
# Current count  2207
# Current count  2208
# Current count  2209
# Current count  2210
# Current count  2211
# Current count  2212
# Current count  2213
# Current count  2214
# Current count  2215
# Current count  2216
# Current count  2217
# Current count  2218
# Current count  2219
# Current count  2220
# Current count  2221
# Current count  2222
# Current count  2223
# Current count  2224
# Current count  2225
# Current count  2226
# Current count  2227
# Current count  2228
# Current count  2229
# Current count  2230
# Current count  2231
# Current count  2232
# Current count  2233
# Current count  2234
# Current count  2235
# Current count  2236
# Current count  2237
# Current count  2238
# Current count  2239
# Current count  2240
# Current count  2241
# Current count  2242
# Current count  2243
# Current count  2244
# Current count  2245
# Current count  2246
# Current count  2247
# Current count  2248
# Current count  2249
# Current count  2250
# Current count  2251
# Current count  2252
# Current count  2253
# Current count  2254
# Current count  2255
# Current count  2256
# Current count  2257
# Current count  2258
# Current count  2259
# Current count  2260
# Current count  2261
# Current count  2262
# Current count  2263
# Current count  2264
# Current count  2265
# Current count  2266
# Current count  2267
# Current count  2268
# Current count  2269
# Current count  2270
# Current count  2271
# Current count  2272
# Current count  2273
# Current count  2274
# Current count  2275
# Current count  2276
# Current count  2277
# Current count  2278
# Current count  2279
# Current count  2280
# Current count  2281
# Current count  2282
# Current count  2283
# Current count  2284
# Current count  2285
# Current count  2286
# Current count  2287
# Current count  2288
# Current count  2289
# Current count  2290
# Current count  2291
# Current count  2292
# Current count  2293
# Current count  2294
# Current count  2295
# Current count  2296
# Current count  2297
# Current count  2298
# Current count  2299
# Current count  2300
# Current count  2301
# Current count  2302
# Current count  2303
# Current count  2304
# Current count  2305
# Current count  2306
# Current count  2307
# Current count  2308
# Current count  2309
# Current count  2310
# Current count  2311
# Current count  2312
# Current count  2313
# Current count  2314
# Current count  2315
# Current count  2316
# Current count  2317
# Current count  2318
# Current count  2319
# Current count  2320
# Current count  2321
# Current count  2322
# Current count  2323
# Current count  2324
# Current count  2325
# Current count  2326
# Current count  2327
# Current count  2328
# Current count  2329
# Current count  2330
# Current count  2331
# Current count  2332
# Current count  2333
# Current count  2334
# Current count  2335
# Current count  2336
# Current count  2337
# Current count  2338
# Current count  2339
# Current count  2340
# Current count  2341
# Current count  2342
# Current count  2343
# Current count  2344
# Current count  2345
# Current count  2346
# Current count  2347
# Current count  2348
# Current count  2349
# Current count  2350
# Current count  2351
# Current count  2352
# Current count  2353
# Current count  2354
# Current count  2355
# Current count  2356
# Current count  2357
# Current count  2358
# Current count  2359
# Current count  2360
# Current count  2361
# Current count  2362
# Current count  2363
# Current count  2364
# Current count  2365
# Current count  2366
# Current count  2367
# Current count  2368
# Current count  2369
# Current count  2370
# Current count  2371
# Current count  2372
# Current count  2373
# Current count  2374
# Current count  2375
# Current count  2376
# Current count  2377
# Current count  2378
# Current count  2379
# Current count  2380
# Current count  2381
# Current count  2382
# Current count  2383
# Current count  2384
# Current count  2385
# Current count  2386
# Current count  2387
# Current count  2388
# Current count  2389
# Current count  2390
# Current count  2391
# Current count  2392
# Current count  2393
# Current count  2394
# Current count  2395
# Current count  2396
# Current count  2397
# Current count  2398
# Current count  2399
# [  is_premium       title                                problem_description  \
# 0      False  1. Two Sum  Given an array of integers nums and an integer...
#
#               topic_tags accepted submission discussion_count  likes  \
# 0  'Array', 'Hash Table'    15.4M      28.4M             1.1K  59.2K
#
#                                    similar_questions
# 0  '3Sum', '4Sum', 'Two Sum II - Input Array Is S...  ,   is_premium               title  \
# 0      False  2. Add Two Numbers
#
#                                  problem_description  \
# 0  You are given two non-empty linked lists repre...
#
#                            topic_tags accepted submission discussion_count  \
# 0  'Linked List', 'Math', 'Recursion'     5.2M      11.7M              739
#
#    likes                                  similar_questions
# 0  32.3K  'Multiply Strings', 'Add Binary', 'Sum of Two ...  ,   is_premium                                              title  \
# 0      False  3. Longest Substring Without Repeating Characters
#
#                                  problem_description  \
# ...
#
#                      topic_tags accepted submission discussion_count likes  \
# 0  'Array', 'Greedy', 'Sorting'    21.7K      38.1K               39   370
#
#                                    similar_questions
# 0  'Coin Change', 'Most Expensive Item That Can N...  ,   is_premium                            title  \
# 0      False  2953. Count Complete Substrings
#
#                                  problem_description  \
# 0  You are given a string word and an integer k.\...
#
#                                  topic_tags accepted submission  \
# 0  'Hash Table', 'String', 'Sliding Window'     7.7K        28K
#
#   discussion_count likes                                  similar_questions
# 0               18   215  'Number of Substrings Containing All Three Cha...  ,   is_premium                                          title  \
# 0      False  2954. Count the Number of Infection Sequences
#
#                                  problem_description  \
# 0  You are given an integer n and an array sick s...
#
#                          topic_tags accepted submission discussion_count  \
# 0  'Array', 'Math', 'Combinatorics'     3.5K      10.2K                9
#
#   likes                                  similar_questions
# 0   119  'Contain Virus', 'Amount of Time for Binary Tr...  ,   is_premium                                          title  \
# 0      False  2956. Find Common Elements Between Two Arrays
#
#                                  problem_description             topic_tags  \
# 0  You are given two integer arrays nums1 and num...  'Array', 'Hash Table'
#
#   accepted submission discussion_count likes similar_questions
# 0      71K      84.8K               21   239                    ,   is_premium                                          title  \
# 0      False  2957. Remove Adjacent Almost-Equal Characters
#
#                                  problem_description  \
# 0  You are given a 0-indexed string word.\nIn one...
#
#                                   topic_tags accepted submission  \
# 0  'String', 'Dynamic Programming', 'Greedy'    23.7K      45.5K
#
#   discussion_count likes                                  similar_questions
# 0               15   176  'Minimum Changes To Make Alternating Binary St...  ,   is_premium                                              title  \
# 0      False  2958. Length of Longest Subarray With at Most ...
#
#                                  problem_description  \
# 0  You are given an integer array nums and an int...
#
#                                 topic_tags accepted submission  \
# 0  'Array', 'Hash Table', 'Sliding Window'   157.9K       283K
#
#   discussion_count likes                                  similar_questions
# 0              128  1.1K  'Longest Substring with At Least K Repeating C...  ,   is_premium                                              title  \
# 0      False  2959. Number of Possible Sets of Closing Branches
#
#                                  problem_description  \
# 0  There is a company with n branches across the ...
#
#                                           topic_tags accepted submission  \
# 0  'Bit Manipulation', 'Graph', 'Heap (Priority Q...     7.8K      15.3K
#
#   discussion_count likes similar_questions
# 0               14   168                    ,   is_premium                                             title  \
# 0      False  2960. Count Tested Devices After Test Operations
#
#                                  problem_description  \
# 0  You are given a 0-indexed integer array batter...
#
#                           topic_tags accepted submission discussion_count  \
# 0  'Array', 'Simulation', 'Counting'    44.9K      56.4K               11
#
#   likes similar_questions
# 0   146                    ,   is_premium                                title  \
# 0      False  2961. Double Modular Exponentiation
#
#                                  problem_description  \
# 0  You are given a 0-indexed 2D array variables w...
#
#                       topic_tags accepted submission discussion_count likes  \
# 0  'Array', 'Math', 'Simulation'    22.2K      46.3K               17   115
#
#   similar_questions
# 0                    ,   is_premium                                              title  \
# 0      False  2962. Count Subarrays Where Max Element Appear...
#
#                                  problem_description  \
# 0  You are given an integer array nums and a posi...
#
#                   topic_tags accepted submission discussion_count likes  \
# 0  'Array', 'Sliding Window'   137.1K     233.7K              147  1.2K
#
#                                    similar_questions
# 0  'Find the Number of Subarrays Where Boundary E...  ,   is_premium                                      title  \
# 0      False  2963. Count the Number of Good Partitions
#
#                                  problem_description  \
# 0  You are given a 0-indexed array nums consistin...
#
#                                        topic_tags accepted submission  \
# 0  'Array', 'Hash Table', 'Math', 'Combinatorics'    11.5K      24.3K
#
#   discussion_count likes                                  similar_questions
# 0               11   252  'Check if There is a Valid Partition For The A...  ,   is_premium                                   title  \
# 0      False  2965. Find Missing and Repeated Values
#
#                                  problem_description  \
# 0  You are given a 0-indexed 2D integer matrix gr...
#
#                                 topic_tags accepted submission  \
# 0  'Array', 'Hash Table', 'Math', 'Matrix'    63.3K      83.3K
#
#   discussion_count likes similar_questions
# 0               25   242                    ,   is_premium                                              title  \
# 0      False  2966. Divide Array Into Arrays With Max Differ...
#
#                                  problem_description  \
# 0  You are given an integer array nums of size n ...
#
#                      topic_tags accepted submission discussion_count likes  \
# 0  'Array', 'Greedy', 'Sorting'   155.5K     216.4K              140   844
#
#   similar_questions
# 0                    ,   is_premium                                           title  \
# 0      False  2967. Minimum Cost to Make Array Equalindromic
#
#                                  problem_description  \
# 0  You are given a 0-indexed integer array nums h...
#
#                                           topic_tags accepted submission  \
# 0  'Array', 'Math', 'Binary Search', 'Greedy', 'S...    13.7K      61.7K
#
#   discussion_count likes                                  similar_questions
# 0               26   229  'Minimum Moves to Equal Array Elements II', 'M...  ,   is_premium                                              title  \
# 0      False  2968. Apply Operations to Maximize Frequency S...
#
#                                  problem_description  \
# 0  You are given a 0-indexed integer array nums a...
#
#                                           topic_tags accepted submission  \
# 0  'Array', 'Binary Search', 'Sliding Window', 'S...     7.2K      19.3K
#
#   discussion_count likes                         similar_questions
# 0                8   256  'Frequency of the Most Frequent Element'  ,   is_premium                                              title  \
# 0      False  2970. Count the Number of Incremovable Subarra...
#
#                                  problem_description  \
# 0  You are given a 0-indexed array of positive in...
#
#                                           topic_tags accepted submission  \
# 0  'Array', 'Two Pointers', 'Binary Search', 'Enu...    22.5K      42.3K
#
#   discussion_count likes                                  similar_questions
# 0               33   166  'Shortest Subarray to be Removed to Make Array...  ,   is_premium                                          title  \
# 0      False  2971. Find Polygon With the Largest Perimeter
#
#                                  problem_description  \
# 0  You are given an array of positive integers nu...
#
#                                    topic_tags accepted submission  \
# 0  'Array', 'Greedy', 'Sorting', 'Prefix Sum'   137.3K     208.9K
#
#   discussion_count likes                        similar_questions
# 0               90   798  '3Sum Smaller', 'Valid Triangle Number'  ,   is_premium                                              title  \
# 0      False  2972. Count the Number of Incremovable Subarra...
#
#                                  problem_description  \
# 0  You are given a 0-indexed array of positive in...
#
#                                  topic_tags accepted submission  \
# 0  'Array', 'Two Pointers', 'Binary Search'     8.7K      21.9K
#
#   discussion_count likes                                  similar_questions
# 0               17   218  'Shortest Subarray to be Removed to Make Array...  ,   is_premium                                              title  \
# 0      False  2973. Find Number of Coins to Place in Tree Nodes
#
#                                  problem_description  \
# 0  You are given an undirected tree with n nodes ...
#
#                                           topic_tags accepted submission  \
# 0  'Dynamic Programming', 'Tree', 'Depth-First Se...     8.9K      24.3K
#
#   discussion_count likes                                  similar_questions
# 0                9   182  'Collect Coins in a Tree', 'Find the Maximum S...  ,   is_premium                      title  \
# 0      False  2974. Minimum Number Game
#
#                                  problem_description  \
# 0  You are given a 0-indexed integer array nums o...
#
#                                           topic_tags accepted submission  \
# 0  'Array', 'Sorting', 'Heap (Priority Queue)', '...    97.8K     114.3K
#
#   discussion_count likes similar_questions
# 0               17   242                    ,   is_premium                                              title  \
# 0      False  2975. Maximum Square Area by Removing Fences F...
#
#                                  problem_description  \
# 0  There is a large (m - 1) x (n - 1) rectangular...
#
#                              topic_tags accepted submission discussion_count  \
# 0  'Array', 'Hash Table', 'Enumeration'    15.2K      64.5K               34
#
#   likes                       similar_questions
# 0   143  'Maximize Area of Square Hole in Grid'  ,   is_premium                                   title  \
# 0      False  2976. Minimum Cost to Convert String I
#
#                                  problem_description  \
# 0  You are given two 0-indexed strings source and...
#
#                                     topic_tags accepted submission  \
# 0  'Array', 'String', 'Graph', 'Shortest Path'   103.3K     177.8K
#
#   discussion_count likes                                  similar_questions
# 0              142   887  'Can Convert String in K Moves', 'Minimum Move...  ,   is_premium                                    title  \
# 0      False  2977. Minimum Cost to Convert String II
#
#                                  problem_description  \
# 0  You are given two 0-indexed strings source and...
#
#                                           topic_tags accepted submission  \
# 0  'Array', 'String', 'Dynamic Programming', 'Gra...     5.3K        21K
#
#   discussion_count likes                                  similar_questions
# 0               17   103  'Can Convert String in K Moves', 'Minimum Move...  ,   is_premium                                         title  \
# 0      False  2980. Check if Bitwise OR Has Trailing Zeros
#
#                                  problem_description  \
# 0  You are given an array of positive integers nu...
#
#                     topic_tags accepted submission discussion_count likes  \
# 0  'Array', 'Bit Manipulation'    36.9K      52.6K                7   109
#
#                                    similar_questions
# 0  'Count Odd Numbers in an Interval Range', 'Rem...  ,   is_premium                                              title  \
# 0      False  2981. Find Longest Special Substring That Occu...
#
#                                  problem_description  \
# 0  You are given a string s that consists of lowe...
#
#                                           topic_tags accepted submission  \
# 0  'Hash Table', 'String', 'Binary Search', 'Slid...   118.6K     190.7K
#
#   discussion_count likes                                  similar_questions
# 0              122   655  'Longest Substring Without Repeating Character...  ,   is_premium                                              title  \
# 0      False  2982. Find Longest Special Substring That Occu...
#
#                                  problem_description  \
# 0  You are given a string s that consists of lowe...
#
#                                           topic_tags accepted submission  \
# 0  'Hash Table', 'String', 'Binary Search', 'Slid...    25.4K      66.4K
#
#   discussion_count likes                                  similar_questions
# 0               28   362  'Longest Substring Without Repeating Character...  ,   is_premium                                   title  \
# 0      False  2983. Palindrome Rearrangement Queries
#
#                                  problem_description  \
# 0  You are given a 0-indexed string s having an e...
#
#                              topic_tags accepted submission discussion_count  \
# 0  'Hash Table', 'String', 'Prefix Sum'     3.4K      13.3K               14
#
#   likes                           similar_questions
# 0    89  'Longest Chunked Palindrome Decomposition'  ,   is_premium                                              title  \
# 0      False  2996. Smallest Missing Integer Greater Than Se...
#
#                                  problem_description  \
# 0  You are given a 0-indexed array of integers nu...
#
#                          topic_tags accepted submission discussion_count  \
# 0  'Array', 'Hash Table', 'Sorting'    35.1K     105.9K               60
#
#   likes                                  similar_questions
# 0   122  'Longest Common Prefix', 'First Missing Positi...  ,   is_premium                                              title  \
# 0      False  2997. Minimum Number of Operations to Make Arr...
#
#                                  problem_description  \
# 0  You are given a 0-indexed integer array nums a...
#
#                     topic_tags accepted submission discussion_count likes  \
# 0  'Array', 'Bit Manipulation'   113.8K     132.5K              103   590
#
#                        similar_questions
# 0  'Minimum Bit Flips to Convert Number'  ,   is_premium                                              title  \
# 0      False  2998. Minimum Number of Operations to Make X a...
#
#                                  problem_description  \
# 0  You are given two positive integers x and y.\n...
#
#                                           topic_tags accepted submission  \
# 0  'Dynamic Programming', 'Breadth-First Search',...    22.3K      47.3K
#
#   discussion_count likes                                  similar_questions
# 0               25   259  'Shortest Bridge', 'Minimum Moves to Spread St...  ,   is_premium                                        title  \
# 0      False  2999. Count the Number of Powerful Integers
#
#                                  problem_description  \
# 0  You are given three integers start, finish, an...
#
#                                 topic_tags accepted submission  \
# 0  'Math', 'String', 'Dynamic Programming'     5.4K      20.3K
#
#   discussion_count likes                                  similar_questions
# 0                7   109  'Powerful Integers', 'Numbers With Repeated Di...  ,   is_premium                                             title  \
# 0      False  3000. Maximum Area of Longest Diagonal Rectangle
#
#                                  problem_description topic_tags accepted  \
# 0  You are given a 2D 0-indexed integer array dim...    'Array'    38.7K
#
#   submission discussion_count likes similar_questions
# 0     106.3K               15   109                    ]

# %%
df2 = pd.read_csv('x2.csv')

# %% [markdown]
# <center> <h2 style="color:blue"> Result of Second Section: </h2> </center>

# %% [markdown]
# <p>This is the sample Dataframe : </p>

# %% [markdown]
# <img src="https://i.imgur.com/kKCZWQy.png">

# %% [markdown]
# <h2> Third Section :</h2>

# %% [markdown]
# <p> Combine Both Part of The DataFrame: </p>

# %%
df = df1.merge(df2, left_on='title', right_on='title', how='left')

# %%
df.to_csv('leetcode_scraped_data.csv', index=None)

# %% [markdown]
# <center> <h2 style="color:blue"> Result of Third Section: </h2> </center>

# %% [markdown]
# <p style="font-size: 18px"><b> Information about a DataFrame:</b></p>

# %% [markdown]
# <p>This is the sample Dataframe : </p>
#
# ```python
# df[:3].T
# ```
#
# <img src="https://i.imgur.com/DJgcuOP.png">

# %% [markdown]
# - We have data of 3000 LeetCode problems.

# %% [markdown]
# **Future Work**
#
# - Finding ways to improve upon the code and documentation of this project
# - Parallelizing the code to make the scaping process simpler and faster
# - Automating this script to run every week to get the latest data
# - Getting information about the premium data

# %% [markdown]
# **References**
#
# 1. Selenium Documentation: https://www.selenium.dev/selenium/docs/api/py/api.html
# 2. Selenium-Python Documentation https://selenium-python.readthedocs.io/
# 3. Beautiful Soup Documentation https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# 4. Stackoverflow https://stackoverflow.com/
